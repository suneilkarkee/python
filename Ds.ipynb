# %% [markdown]
# Understanding List

# %%
print("hello world")
# Out:
# hello world

# %%
num=[1,2,3,4,5]
num.append(6)
num.remove(3)
print(num)
# Out:
# [1, 2, 4, 5, 6]

# %%
print("goodbye world")
# Out:
# goodbye world

# %%
print(3+4)
# Out:
# 7

# %%
# Creating a list
fruits = ["apple", "banana", "cherry"]
print("Original list:", fruits)

# Adding elements
fruits.append("orange")        # add at end
fruits.insert(1, "mango")      # insert at specific position
print("After adding:", fruits)

# Removing elements
fruits.remove("banana")        # remove by value
popped_item = fruits.pop()     # remove last item
print("After removing:", fruits)
print("Popped item:", popped_item)

# Accessing elements
print("First item:", fruits[0])
print("Last item:", fruits[-1])

# Slicing list
print("First two items:", fruits[:2])

# Updating elements
fruits[1] = "grape"
print("After update:", fruits)

# Looping through list
print("Looping through list:")
for fruit in fruits:
    print(fruit)

# Sorting list
fruits.sort()
print("Sorted list:", fruits)

# Reversing list
fruits.reverse()
print("Reversed list:", fruits)
# Out:
# Original list: ['apple', 'banana', 'cherry']
# After adding: ['apple', 'mango', 'banana', 'cherry', 'orange']
# After removing: ['apple', 'mango', 'cherry']
# Popped item: orange
# First item: apple
# Last item: cherry
# First two items: ['apple', 'mango']
# After update: ['apple', 'grape', 'cherry']
# Looping through list:
# apple
# grape
# cherry
# Sorted list: ['apple', 'cherry', 'grape']
# Reversed list: ['grape', 'cherry', 'apple']

# %% [markdown]
# Decorators

# %%
def my_decorator(func):
    def wrapper (a, b):
        print("Here the addition of two numbers will be performed")
        return func(a,b)
        print
    return wrapper

@my_decorator
def add_numbers(x, y):
    print(x + y)
    return 0


add_numbers(5, 10)
# Out:
# Here the addition of two numbers will be performed
# 15
# 0

# %%
class Counter:
    def __init__(self, max_value):
        self.max_value = max_value
        self.current = 1

    def __iter__(self):
        return self

    def __next__(self):
        if self.current <= self.max_value:
            value = self.current
            self.current += 1
            return value
        else:
            raise StopIteration


def main():
    counter = Counter(5)

    for number in counter:
        print(number)


if __name__ == "__main__":
    main()
# Out:
# 1
# 2
# 3
# 4
# 5
